# %%
# Dependencies
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import pymongo
import time 
from IPython import get_ipython
import nbconvert

# %% [markdown]
# Read in Table from URL as Data Frame

# %%
rep_url = 'https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population'

df = pd.read_html(rep_url)[0]
df
# Out:
#       Rank                                              State  \
#    Current  2010                                        State
# 0      1.0   1.0                                   California
# 1      2.0   2.0                                        Texas
# 2      3.0   4.0                                      Florida
# 3      4.0   3.0                                     New York
# 4      5.0   6.0                                 Pennsylvania
# 5      6.0   5.0                                     Illinois
# 6      7.0   7.0                                         Ohio
# 7      8.0   9.0                                      Georgia
# 8      9.0  10.0                               North Carolina
# 9     10.0   8.0                                     Michigan
# 10    11.0  11.0                                   New Jersey
# 11    12.0  12.0                                     Virginia
# 12    13.0  13.0                                   Washington
# ...

# %% [markdown]
# Flatten Multi-Level Index

# %%
df.columns = df.columns.get_level_values(0)

#df.columns = [' '.join(col).strip() for col in df.columns.values]

df
# Out:
#     Rank  Rank                                        State Census population  \
# 0    1.0   1.0                                   California          39512223
# 1    2.0   2.0                                        Texas          28995881
# 2    3.0   4.0                                      Florida          21477737
# 3    4.0   3.0                                     New York          19453561
# 4    5.0   6.0                                 Pennsylvania          12801989
# 5    6.0   5.0                                     Illinois          12671821
# 6    7.0   7.0                                         Ohio          11689100
# 7    8.0   9.0                                      Georgia          10617423
# 8    9.0  10.0                               North Carolina          10488084
# 9   10.0   8.0                                     Michigan           9986857
# 10  11.0  11.0                                   New Jersey           8882190
# ...

# %% [markdown]
# Select Relevant Columns

# %%
df = df[['State', 'Census population', 'Total U.S. House of Representatives Seats']]
df
# Out:
#                                           State Census population  \
# 0                                    California          39512223
# 1                                         Texas          28995881
# 2                                       Florida          21477737
# 3                                      New York          19453561
# 4                                  Pennsylvania          12801989
# 5                                      Illinois          12671821
# 6                                          Ohio          11689100
# 7                                       Georgia          10617423
# 8                                North Carolina          10488084
# 9                                      Michigan           9986857
# 10                                   New Jersey           8882190
# 11                                     Virginia           8535519
# 12                                   Washington           7614893
# ...

# %% [markdown]
# Rename 2010 Census Column to Address Duplicate Column Names

# %%
column_names = df.columns.values
column_names[2] = "2010 Census Population"
df.columns = column_names
df
# Out:
#                                           State Census population  \
# 0                                    California          39512223
# 1                                         Texas          28995881
# 2                                       Florida          21477737
# 3                                      New York          19453561
# 4                                  Pennsylvania          12801989
# 5                                      Illinois          12671821
# 6                                          Ohio          11689100
# 7                                       Georgia          10617423
# 8                                North Carolina          10488084
# 9                                      Michigan           9986857
# 10                                   New Jersey           8882190
# 11                                     Virginia           8535519
# 12                                   Washington           7614893
# ...

# %% [markdown]
# Drop Estimated Unnecessary Estimated Population Column

# %%
df = df.drop(df.columns[1], axis=1)
df
# Out:
#                                           State 2010 Census Population  \
# 0                                    California               37253956
# 1                                         Texas               25145561
# 2                                       Florida               18801310
# 3                                      New York               19378102
# 4                                  Pennsylvania               12702379
# 5                                      Illinois               12830632
# 6                                          Ohio               11536504
# 7                                       Georgia                9687653
# 8                                North Carolina                9535483
# 9                                      Michigan                9883640
# 10                                   New Jersey                8791894
# 11                                     Virginia                8001024
# ...

# %% [markdown]
# Replace Values for House of Representatives Seats w/ NaN for non-State Rows and Drop NaNs

# %%
representation_df = df.replace({'1 (non-voting)': np.NaN, '435 (+ 1 non-voting)': np.NaN, '435 (+ 6 non-voting)': np.NaN, 
                         '432': np.NaN, '435': np.NaN})

representation_df = representation_df.dropna()
representation_df
# Out:
#              State 2010 Census Population  \
# 0       California               37253956
# 1            Texas               25145561
# 2          Florida               18801310
# 3         New York               19378102
# 4     Pennsylvania               12702379
# 5         Illinois               12830632
# 6             Ohio               11536504
# 7          Georgia                9687653
# 8   North Carolina                9535483
# 9         Michigan                9883640
# 10      New Jersey                8791894
# 11        Virginia                8001024
# 12      Washington                6724540
# 13         Arizona                6392017
# 14   Massachusetts                6547629
# 15       Tennessee                6346105
# 16         Indiana                6483802
# 17        Missouri                5988927
# 18        Maryland                5773552
# 19       Wisconsin                5686986
# 20        Colorado                5029196
# ...

# %% [markdown]
# Reset Index to Avoid Confusion

# %%
representation_df = representation_df.reset_index(drop=True)

representation_df
# Out:
#              State 2010 Census Population  \
# 0       California               37253956
# 1            Texas               25145561
# 2          Florida               18801310
# 3         New York               19378102
# 4     Pennsylvania               12702379
# 5         Illinois               12830632
# 6             Ohio               11536504
# 7          Georgia                9687653
# 8   North Carolina                9535483
# 9         Michigan                9883640
# 10      New Jersey                8791894
# 11        Virginia                8001024
# 12      Washington                6724540
# 13         Arizona                6392017
# 14   Massachusetts                6547629
# 15       Tennessee                6346105
# 16         Indiana                6483802
# 17        Missouri                5988927
# 18        Maryland                5773552
# 19       Wisconsin                5686986
# 20        Colorado                5029196
# ...

# %%
representation_df['senate_seats'] = 2
electoral_college_col = representation_df['Total U.S. House of Representatives Seats'].astype(int) + 2
representation_df['electoral_college_votes'] = electoral_college_col
representation_df = representation_df.rename(columns = {'2010 Census Population': '2010_census_population',
                                                        'Total U.S. House of Representatives Seats': 'house_of_reps_seats'
                                                       })
representation_df['pop/senator'] = representation_df['2010_census_population'].astype(int) / representation_df['senate_seats'] / 1000000
representation_df['pop/rep'] = representation_df['2010_census_population'].astype(int) / representation_df['house_of_reps_seats'].astype(int) / 1000000
representation_df['pop/elector'] = representation_df['2010_census_population'].astype(int) / representation_df['electoral_college_votes'].astype(int) / 1000000
representation_df
# Out:
#              State 2010_census_population house_of_reps_seats  senate_seats  \
# 0       California               37253956                  53             2
# 1            Texas               25145561                  36             2
# 2          Florida               18801310                  27             2
# 3         New York               19378102                  27             2
# 4     Pennsylvania               12702379                  18             2
# 5         Illinois               12830632                  18             2
# 6             Ohio               11536504                  16             2
# 7          Georgia                9687653                  14             2
# 8   North Carolina                9535483                  13             2
# 9         Michigan                9883640                  14             2
# 10      New Jersey                8791894                  12             2
# ...

# %% [markdown]
# Read in Federal Funding CSV (Soure: https://worldpopulationreview.com/state-rankings/federal-aid-by-state)

# %%
funding_df = pd.read_csv('federal-aid-by-state.csv')
funding_df
# Out:
#              State  federalFunding  totalFederalFunding  benefitsRecipients  \
# 0         Virginia           10301         1.768000e+11                 8.1
# 1         Kentucky            9145         7.080000e+10                14.1
# 2       New Mexico            8692         3.170000e+10                17.4
# 3    West Virginia            7283         2.460000e+10                16.8
# 4           Alaska            7048         1.300000e+10                10.8
# 5      Mississippi            6880         3.780000e+10                15.3
# 6          Alabama            6694         6.580000e+10                14.0
# 7         Maryland            6035         1.051000e+11                10.3
# 8            Maine            5572         1.740000e+10                12.8
# 9           Hawaii            5270         1.990000e+10                10.7
# 10        Arkansas            5080         3.510000e+10                11.8
# ...

# %%
funding_df = funding_df.rename(columns = {'State':'state','federalFunding': 'per_capita_fed_funding', 
                                         'totalFederalFunding': 'total_fed_funding_billions', 
                                         'benefitsRecipients': 'benefits_receipients_percent',
                                        'medianHouseholdIncome': 'median_household_income_billions'})

funding_df['total_fed_funding_billions'] = funding_df['total_fed_funding_billions'] / 1000000000

funding_df
# Out:
#              state  per_capita_fed_funding  total_fed_funding_billions  \
# 0         Virginia                   10301                       176.8
# 1         Kentucky                    9145                        70.8
# 2       New Mexico                    8692                        31.7
# 3    West Virginia                    7283                        24.6
# 4           Alaska                    7048                        13.0
# 5      Mississippi                    6880                        37.8
# 6          Alabama                    6694                        65.8
# 7         Maryland                    6035                       105.1
# 8            Maine                    5572                        17.4
# 9           Hawaii                    5270                        19.9
# 10        Arkansas                    5080                        35.1
# 11  South Carolina                    5008                        59.7
# ...

# %%
# (https://electionlab.mit.edu/data)
elect_df = pd.read_csv('1976-2018-senate.csv')
elect_df
# Out:
#       year      state state_po  state_fips  state_cen  state_ic     office  \
# 0     1976    Arizona       AZ           4         86        61  US Senate
# 1     1976    Arizona       AZ           4         86        61  US Senate
# 2     1976    Arizona       AZ           4         86        61  US Senate
# 3     1976    Arizona       AZ           4         86        61  US Senate
# 4     1976    Arizona       AZ           4         86        61  US Senate
# ...    ...        ...      ...         ...        ...       ...        ...
# 3416  2018  Wisconsin       WI          55         35        25  US Senate
# 3417  2018    Wyoming       WY          56         83        68  US Senate
# 3418  2018    Wyoming       WY          56         83        68  US Senate
# 3419  2018    Wyoming       WY          56         83        68  US Senate
# 3420  2018    Wyoming       WY          56         83        68  US Senate
#
# ...

# %%
for label, row in elect_df.iterrows():
    print(label)
    print(row)
# Out:
# 0
# year                     1976
# state                 Arizona
# state_po                   AZ
# state_fips                  4
# state_cen                  86
# state_ic                   61
# office              US Senate
# district            statewide
# stage                     gen
# special                 False
# candidate         Sam Steiger
# party              republican
# writein                 False
# mode                    total
# candidatevotes         321236
# totalvotes             741210
# unofficial              False
# version            2.0171e+07
# Name: 0, dtype: object
# 1
# year                             1976
# state                         Arizona
# state_po                           AZ
# state_fips                          4
# state_cen                          86
# state_ic                           61
# office                      US Senate
# district                    statewide
# stage                             gen
# ...

# %%
#elect_url = 'https://en.wikipedia.org/wiki/List_of_United_States_Senate_election_results_by_state'

#elect_df = pd.read_html(elect_url)[2]

#elect_df

# %%
#elect_df = elect_df.head(50)
#elect_df.drop(elect_df.index([[50, 57]])
#elect_df.index
#elect_df

# %%
#elect_df = elect_df.dropna(axis=1, inplace = False)
#elect_df

# %%
#print(elect_df.index.tolist())
#print(elect_df.columns.nlevels)

# %%
#elect_df = elect_df.iloc[:, 1:]
#elect_df = elect_df.dropindex
#elect_df.columns = elect_df.columns.get_level_values(1)
#elect_df.columns
#elect_df

# %%
#elect_df = elect_df[["state", "dem_votes_1968-2016", "rep_votes_1968-2016", 
                    "other_votes_1968-2016", "percent_dem_votes_1968-2016"]]

#elect_df
# Out:
#   File "<ipython-input-18-d2e1c930b1f7>", line 2
#     "other_votes_1968-2016", "percent_dem_votes_1968-2016"]]
#     ^
# IndentationError: unexpected indent

# %%
senate2018_df = pd.read_csv('senate2018.csv', encoding='cp1252')
senate2018_df

# %%
senate2018_df.columns

# %%
senate2018_df = senate2018_df[['STATE', 'PARTY', 'GE WINNER INDICATOR']]
senate2018_df

# %%
senate2018_df = senate2018_df.dropna()
senate2018_df = senate2018_df.reset_index()
senate2018_df = senate2018_df[['STATE', 'PARTY']]
senate2018_df

# %%
senate2018_df.replace(to_replace ="DFL", 
                 value ="D")

senate2018_df

# %%
#senate2018_url = 'https://en.wikipedia.org/wiki/2018_United_States_Senate_elections'

#senate2018_df = pd.read_html(senate2018_url)[9]

#senate2018_df

# %%
#senate2018_df.columns = senate2018_df.columns.get_level_values(1)
#senate2018_df = senate2018_df[["State", "Result"]]

#column_names3 = senate2018_df.columns.values
#column_names3[0] = "state"
#column_names3[1] = "result"


#senate2018_df.columns = column_names3

#senate2018_df['result'] = senate2018_df['result'].astype(str)
#senate2018_df

# %%
#senate2018_df = senate2018_df.head(35)
#senate2018_df

# %%
#senate2018_list = {}

#for i in senate2018_df:

# %%
#senate2018_df.dtypes

# %%
import psycopg2
import sqlalchemy
import matplotlib as plt

# %matplotlib inline

# %%
from sqlalchemy import create_engine

# %%
postgresStr = "postgresql://postgres:password@localhost:5433/representation_db"
engine = create_engine(postgresStr)
conn = engine.connect()

print(engine.table_names())

# %%
representation_df.to_sql('representation', conn)
funding_df.to_sql('funding', conn)
elect_df.to_sql('elections', conn)

print('Success')
